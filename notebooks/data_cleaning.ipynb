# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('online_retail_II.csv')

# %%
df.shape
# Out:
# (47114, 8)

# %%
df.isna().sum()
# Out:
# Invoice            0
# StockCode          0
# Description      262
# Quantity           1
# InvoiceDate        1
# Price              1
# Customer ID    13522
# Country            1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47114 entries, 0 to 47113
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice      47114 non-null  object
#  1   StockCode    47114 non-null  object
#  2   Description  46852 non-null  object
#  3   Quantity     47113 non-null  float64
#  4   InvoiceDate  47113 non-null  object
#  5   Price        47113 non-null  float64
#  6   Customer ID  33592 non-null  float64
#  7   Country      47113 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 2.9+ MB

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1  489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2  489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df.describe()
# Out:
#            Quantity         Price   Customer ID
# count  47113.000000  47113.000000  33592.000000
# mean       9.508289      4.335300  15465.050548
# std       60.201466     21.233927   1665.783870
# min    -1395.000000      0.000000  12346.000000
# 25%        1.000000      1.250000  14087.000000
# 50%        2.000000      2.570000  15499.000000
# 75%        8.000000      4.950000  16918.000000
# max     5184.000000   1998.490000  18287.000000

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47114 entries, 0 to 47113
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice      47114 non-null  object
#  1   StockCode    47114 non-null  object
#  2   Description  46852 non-null  object
#  3   Quantity     47113 non-null  float64
#  4   InvoiceDate  47113 non-null  datetime64[ns]
#  5   Price        47113 non-null  float64
#  6   Customer ID  33592 non-null  float64
#  7   Country      47113 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ MB

# %%
(df["Quantity"] < 0).sum()
# Out:
# np.int64(1166)

# %%
(df["Price"] < 0).sum()
# Out:
# np.int64(0)

# %%
df[df["Quantity"] == -4200][["Invoice", "Quantity", "Price", "Customer ID"]]
# Out:
# Empty DataFrame
# Columns: [Invoice, Quantity, Price, Customer ID]
# Index: []

# %%
df[(df["Price"] == 0) & (df["Quantity"] < 0)].shape
# Out:
# (96, 8)

# %%
df[(df["Price"] == 0) & (df["Quantity"] < 0)].shape
# Out:
# (96, 8)

# %%
df = df[~((df["Price"] == 0) & (df["Quantity"] < 0))]

# %%
df.shape
# Out:
# (47018, 8)

# %%
df.isna().sum()
# Out:
# Invoice            0
# StockCode          0
# Description      186
# Quantity           1
# InvoiceDate        1
# Price              1
# Customer ID    13426
# Country            1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(524)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (46494, 8)

# %%
df.isnull().sum()
# Out:
# Invoice            0
# StockCode          0
# Description      186
# Quantity           1
# InvoiceDate        1
# Price              1
# Customer ID    13404
# Country            1
# dtype: int64

# %%
(df["Price"] == 0).sum()
# Out:
# np.int64(194)

# %%
df[df["Price"] == 0][["Invoice", "StockCode", "Description", "Quantity", "Price", "Customer ID"]].sample(20)
# Out:
#       Invoice StockCode Description  Quantity  Price  Customer ID
# 43629  493169     72777         NaN      14.0    0.0          NaN
# 43782  493193    35977B         NaN       7.0    0.0          NaN
# 43627  493167     22330         NaN     174.0    0.0          NaN
# 43800  493198     20887         NaN       6.0    0.0          NaN
# 43578  493143     20736         NaN     187.0    0.0          NaN
# 43587  493153    35603B         NaN      12.0    0.0          NaN
# 44502  493285    79309A         NaN       1.0    0.0          NaN
# 21852  491117     20879         NaN      12.0    0.0          NaN
# 43829  493227    84558B         NaN       4.0    0.0          NaN
# 14503  490543     37446         NaN     222.0    0.0          NaN
# 44501  493279    72803B         NaN       3.0    0.0          NaN
# 42011  492835     22187         NaN      48.0    0.0          NaN
# 43585  493149    17164D         NaN     784.0    0.0          NaN
# ...

# %%
df[df["Price"] == 0]["Customer ID"].notna().sum()
# Out:
# np.int64(7)

# %%
df[df["Price"] == 0]["Description"].notna().sum()
# Out:
# np.int64(9)

# %% [markdown]
# # Removed zero-priced transactions as they do not contribute
# # to meaningful revenue analysis or demand forecasting.

# %%
df = df[df["Price"] > 0]

# %%
df.shape
# Out:
# (46299, 8)

# %%
df.isna().sum()
# Out:
# Invoice            0
# StockCode          0
# Description        0
# Quantity           0
# InvoiceDate        0
# Price              0
# Customer ID    13216
# Country            0
# dtype: int64

# %%
(df["Quantity"] < 0).sum()
# Out:
# np.int64(1068)

# %%
df[df["Quantity"] < 0].head(20)
# Out:
#      Invoice StockCode                          Description  Quantity  \
# 178  C489449     22087             PAPER BUNTING WHITE LACE     -12.0
# 179  C489449    85206A         CREAM FELT EASTER EGG BASKET      -6.0
# 180  C489449     21895        POTTING SHED SOW 'N' GROW SET      -4.0
# 181  C489449     21896                   POTTING SHED TWINE      -6.0
# 182  C489449     22083           PAPER CHAIN KIT RETRO SPOT     -12.0
# 183  C489449     21871                  SAVE THE PLANET MUG     -12.0
# 184  C489449     84946      ANTIQUE SILVER TEA GLASS ETCHED     -12.0
# 185  C489449    84970S    HANGING HEART ZINC T-LIGHT HOLDER     -24.0
# 186  C489449     22090            PAPER BUNTING RETRO SPOTS     -12.0
# 196  C489459    90200A           PURPLE SWEETHEART BRACELET      -3.0
# 197  C489459    90200D             PINK SWEETHEART BRACELET      -3.0
# 198  C489459    90200B            BLACK SWEETHEART BRACELET      -3.0
# ...

# %%
df.to_csv("cleaned_retail.csv", index=False)
